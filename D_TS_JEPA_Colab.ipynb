# %% [markdown]
# ## 1. Setup Environment

# %%
# Check GPU availability
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name()}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB
# Memory: 42.5 GB

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Upload Project Files
#
# **Option A:** Upload to Google Drive and access via mounted drive
# **Option B:** Upload directly to Colab (files will be lost when runtime disconnects)
# **Option C:** Clone from GitHub

# %%
# Option A: Access from Google Drive (recommended)
import os

# Change this path to where you uploaded your D-TS-JEPA folder in Google Drive
project_path = '/content/drive/MyDrive/D-JEPA-test'

if os.path.exists(project_path):
    os.chdir(project_path)
    print(f"Changed to project directory: {os.getcwd()}")
else:
    print(f"Project path not found: {project_path}")
    print("Please upload your D-TS-JEPA folder to Google Drive first.")
# Out:
# Changed to project directory: /content/drive/MyDrive/D-JEPA-test

# %%
# Option B: Upload files directly (uncomment if needed)
# from google.colab import files
# uploaded = files.upload()

# Option C: Clone from GitHub (uncomment and modify if your project is on GitHub)
# !git clone https://github.com/yourusername/D-TS-JEPA.git
# os.chdir('/content/D-TS-JEPA')

# %% [markdown]
# ## 3. Install Dependencies

# %%
# Install required packages
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install torchviz
# !pip install numpy pandas matplotlib seaborn
# !pip install scikit-learn
# !pip install tqdm
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %% [markdown]
# ## 4. Verify Project Structure

# %%
# List project files
# !ls -la

# Check if main files exist
import os
required_files = ['PreTrain.py', 'config_files/', 'data/', 'Discrete_JEPA/', 'jepa_classic/', 'VQVAE/']
for file in required_files:
    if os.path.exists(file):
        print(f"✓ {file} found")
    else:
        print(f"✗ {file} missing")
# Out:
# total 41399
# drwx------ 2 root root     4096 Feb  6 10:42 config_files
# drwx------ 2 root root     4096 Feb  6 10:42 data
# drwx------ 2 root root     4096 Feb  6 10:42 data_loaders
# -rw------- 1 root root      444 Dec 28 05:40 Diary
# drwx------ 2 root root     4096 Feb  6 10:42 Discrete_JEPA
# drwx------ 2 root root     4096 Feb  6 10:42 Discrete_JEPA_CNN
# -rw------- 1 root root     6414 Jan  8 00:19 D_TS_JEPA_Colab.ipynb
# -rw------- 1 root root 42318694 Feb  6 11:40 gradient_log.txt
# -rw------- 1 root root       27 Feb  6 10:53 info.csv
# drwx------ 2 root root     4096 Feb  6 10:42 jepa_classic
# drwx------ 2 root root     4096 Feb  6 10:42 latent_analysis
# drwx------ 2 root root     4096 Feb  6 10:42 main
# -rw------- 1 root root     1360 Jan  4 03:44 making_style.py
# -rw------- 1 root root      907 Jan 10 03:39 mask_util.py
# drwx------ 2 root root     4096 Feb  6 10:42 output_model
# -rw------- 1 root root       27 Feb  6 10:53 perplexity_log.csv
# ...

# %% [markdown]
# ## 5. Update Configuration for Colab

# %%
# Update paths for Colab environment
import sys
sys.path.append('/content/D-JEPA-test')  # or your project path

# Check data files
# !ls -la data/
# Out:
# total 258147
# -rw------- 1 root root  95581762 Feb 11  2023 electricity.csv
# -rw------- 1 root root   2589657 Feb 11  2023 ETTh1.csv
# -rw------- 1 root root   2417960 Feb 11  2023 ETTh2.csv
# -rw------- 1 root root  10360719 Feb 11  2023 ETTm1.csv
# -rw------- 1 root root   9677236 Feb 11  2023 ETTm2.csv
# -rw------- 1 root root 136478119 Feb 11  2023 traffic.csv
# -rw------- 1 root root   7235425 Dec 27 05:05 weather.csv

# %% [markdown]
# ## 6. Run Training
#
# Choose which model to train:

# %% [markdown]
# ### Option 3: Train Classic JEPA Model

# %%
# Train Classic JEPA
# !python PreTrain.py --model DescreteJEPA --skip false
# Out:
# Streaming output truncated to the last 5000 lines.
# context: 0.31798726320266724, target: 0.3614155948162079
# 📊 Task Losses - P2P: 0.1827, S2P: 0.1905, VQ: 1.3685
# 📚 Codebook - Using 128/128 entries (100.0%) | Perplexity: 113.90
# 🔧 Regularization - Perplexity Loss: 0.0001
#    VICReg Var: patch=0.6819, token=0.6066
#    VICReg Cov: patch=0.4990, token=0.0139
# ⚖️  Balance - Task: 0.3732 vs Regularization: 0.6956
# semantic_tokens: OK
# context: 0.294257253408432, target: 0.3321002125740051
# semantic_tokens: OK
# context: 0.3171689808368683, target: 0.35905736684799194
# semantic_tokens: OK
# context: 0.32030993700027466, target: 0.3648567199707031
# semantic_tokens: OK
# context: 0.3176969885826111, target: 0.3608561158180237
# semantic_tokens: OK
# context: 0.3104342818260193, target: 0.354966402053833
# 📊 Task Losses - P2P: 0.1796, S2P: 0.1876, VQ: 1.3366
# 📚 Codebook - Using 126/128 entries (98.4%) | Perplexity: 112.54
# 🔧 Regularization - Perplexity Loss: 0.0001
# ...
